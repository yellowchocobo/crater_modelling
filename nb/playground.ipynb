# %%
# common library
import numpy as np
from pathlib import Path
import sys
import os
import glob
import pySALEPlot as psp

# personal crater modelling library
import crater as cr # calculate geomorphology of impact crater
import ejecta as ej # calculate properties of ejected materials, errors when loading this module
# Out:
# ==============================================================
#
#                _____         _      ______ _____  _       _
#               / ____|  /\   | |    |  ____|  __ \| |     | |
#   _ __  _   _| (___   /  \  | |    | |__  | |__) | | ___ | |_
#  | '_ \| | | |\___ \ / /\ \ | |    |  __| |  ___/| |/ _ \| __|
#  | |_) | |_| |____) / ____ \| |____| |____| |    | | (_) | |_
#  | .__/ \__, |_____/_/    \_\______|______|_|    |_|\___/ \__|
#  | |     __/ |
#  |_|    |___/
#                         by Tom Davison
#
# ==============================================================

# %%
method = 3
mode = 1
poros = 1  # if porous = 1, non porous = 0
id_mat = 0  # 0 = everything, 2 only lower material, especially practical in layering modelling
transient = 0 
thresholdf = 0.01
g = 1.62

# %%
path_jdata = "/home/nilscp/iSALE/Dellen/share/examples/demo2D/demo2D/jdata.dat"
model = psp.opendatfile(path_jdata)
# Out:
# Opened iSALE data file '/home/nilscp/iSALE/Dellen/share/examples/demo2D/demo2D/jdata.dat', with 201 time steps

# %%
step0 = model.readStep(['Den'], 0)
step100 = model.readStep(['Den'], 100)
step200 = model.readStep(['Den'], 200)
# Out:
# Read in ['Den'] for timestep 0 (0.000e+00 s)
# Read in ['Den'] for timestep 100 (1.232e+00 s)
# Read in ['Den'] for timestep 200 (2.465e+00 s)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,8))
plt.pcolormesh(model.xc, model.yc, step100.data[0])
# Out:
# <ipython-input-66-7d9b38a2cdbb>:2: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(model.xc, model.yc, step100.data[0])

# %%
plt.figure(figsize=(8,8))
plt.pcolormesh(model.xc, model.yc, step200.data[0])
# Out:
# <ipython-input-67-9be7a18608c7>:2: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(model.xc, model.yc, step200.data[0])
